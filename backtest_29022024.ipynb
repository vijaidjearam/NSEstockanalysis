# %% [markdown]
# <a href="https://colab.research.google.com/github/vijaidjearam/NSEstockanalysis/blob/main/backtest_29022024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Installation of Libraries Required for the RunTime
#
# ---

# %%
# @title
! pip install nsepython
! pip install nselib
# Out:
# Requirement already satisfied: nsepython in /usr/local/lib/python3.10/dist-packages (2.8)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from nsepython) (2.31.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from nsepython) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from nsepython) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->nsepython) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->nsepython) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->nsepython) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->nsepython) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->nsepython) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->nsepython) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->nsepython) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->nsepython) (1.16.0)
# Requirement already satisfied: nselib in /usr/local/lib/python3.10/dist-packages (0.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from nselib) (2.31.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from nselib) (1.5.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from nselib) (1.11.4)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->nselib) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->nselib) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->nselib) (1.25.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->nselib) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->nselib) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->nselib) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->nselib) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->nselib) (1.16.0)

# %% [markdown]
# # Import all the required libraries
#
# ---

# %%
# @title
import pandas as pd
from nsepython import *
from datetime import datetime, timedelta, date
from nselib import capital_market
from dateutil import parser
import math
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %% [markdown]
# # Dependent functions required for the main module
#
# ---

# %%
# @title
def get_index_history_lastweek(symbol):
    start_date = (datetime.today() - timedelta(days=7)).strftime("%m/%d/%Y")
    end_date = datetime.now().strftime("%m/%d/%Y")
    df = pd.DataFrame(index_history(symbol,start_date,end_date))
    print(df)
def get_index_history(symbol,start_date,end_date):
    data = capital_market.index_data(index=symbol,from_date=start_date,to_date=end_date)
    print (data)
    return data
def gethighofstartdate(df,symbol,start_date,end_date):
    filt = (df['TIMESTAMP'] == start_date)
    try:
        result = df.loc[filt,'HIGH_INDEX_VAL'].values[0]
        return float(result)
    except IndexError:
        return "NA"
    except ValueError as ve:
        return ve
def getlowofstartdate(df,symbol,start_date,end_date):
    filt = (df['TIMESTAMP'] == start_date)
    try:
        result = df.loc[filt,'LOW_INDEX_VAL'].values[0]
        return float(result)
    except IndexError:
        return "NA"
    except ValueError as ve:
        return ve
def gethighofenddate(df,symbol,start_date,end_date):
    filt = (df['TIMESTAMP'] == end_date)
    try:
        result = df.loc[filt,'HIGH_INDEX_VAL'].values[0]
        return float(result)
    except IndexError:
        return "NA"
    except ValueError as ve:
        return ve
def getlowofenddate(df,symbol,start_date,end_date):
    filt = (df['TIMESTAMP'] == end_date)
    try:
        result = df.loc[filt,'LOW_INDEX_VAL'].values[0]
        return float(result)
    except IndexError:
        return "NA"
    except ValueError as ve:
        return ve
def derivativehistorycallgetlowvalue(symbol,start_date,end_date,instrumentType,expiry_date,strikePrice):
    optionType = "CE"
    start_date = datetime.strptime(start_date,"%d-%m-%Y")
    start_date = start_date.strftime("%d-%m-%Y")
    end_date = datetime.strptime(end_date,"%d-%m-%Y")
    end_date = end_date.strftime("%d-%m-%Y")
    expiry_date = datetime.strptime(expiry_date,"%d-%m-%Y")
    expiry_date = expiry_date.strftime("%d-%b-%Y")
    try:
        df = pd.DataFrame(derivative_history(symbol,start_date,end_date,instrumentType,expiry_date,strikePrice,optionType))
        result = (df['FH_TRADE_LOW_PRICE'].min())
        return float(result)
    except:
        return "NA"
def derivativehistoryputgetlowvalue(symbol,start_date,end_date,instrumentType,expiry_date,strikePrice,):
    optionType = "PE"
    start_date = datetime.strptime(start_date,"%d-%m-%Y")
    start_date = start_date.strftime("%d-%m-%Y")
    end_date = datetime.strptime(end_date,"%d-%m-%Y")
    end_date = end_date.strftime("%d-%m-%Y")
    expiry_date = datetime.strptime(expiry_date,"%d-%m-%Y")
    expiry_date = expiry_date.strftime("%d-%b-%Y")
    try:
        df = pd.DataFrame(derivative_history(symbol,start_date,end_date,instrumentType,expiry_date,strikePrice,optionType))
        result = (df['FH_TRADE_LOW_PRICE'].min())
        return float(result)
    except:
        return "NA"
def round_up_to_base(x, base=50):
    return x + (base - x) % base
def round_down_to_base(x, base=50):
    return x - (x % base)

def get_end_strike_value(index_symbol,start_date,end_date,expiry_date,instrumentType):
    symbol = index_symbol
    df = get_index_history(symbol,start_date,end_date)
    highofstartdate = gethighofstartdate(df,symbol,start_date,end_date)
    print('highofstartdate : '+ str(highofstartdate))
    lowofstartdate = getlowofstartdate(df,symbol,start_date,end_date)
    print('lowofstartdate: '+ str(lowofstartdate))
    highofenddate = gethighofenddate(df,symbol,start_date,end_date)
    print('highofenddate: '+ str(highofenddate))
    lowofenddate = getlowofenddate(df,symbol,start_date,end_date)
    print('lowofenddate : '+ str(lowofenddate))
    maxof2days = max(highofstartdate,highofenddate)
    print('maxof2days: '+ str(maxof2days))
    minof2days = min(lowofstartdate,lowofenddate)
    print('minof2days :' + str(minof2days))
    bufferhigh = round(maxof2days * 1.0015)
    print('bufferhigh : '+ str(bufferhigh))
    bufferlow = round(minof2days * 0.9985)
    print('bufferlow : '+ str(bufferlow))
    callendstrike = round_down_to_base(bufferlow)
    print('callendstrike : '+str(callendstrike))
    putendstrike = round_up_to_base(bufferhigh)
    print('putendstrike : '+str(putendstrike))
    return callendstrike,putendstrike
def get_call_entrystrike(derivative_symbol,start_date,end_date,instrumentType,expiry_date,callendstrike):
    # calculate CallEntryStrike 1st row
    symbol = derivative_symbol
    strike = []
    premium = []
    twodll = []
    strike.append(callendstrike)
    temppremium = callendstrike * (0.85/100)
    premium.append(temppremium)
    temptwodll = float(derivativehistorycallgetlowvalue(symbol,start_date,end_date,instrumentType,expiry_date,strikePrice=strike[0]))
    twodll.append(temptwodll)
     # Call Entry strke 2....n rows
    for i in range(1,9):
        if twodll[-1] >= premium[-1]:
            strike.append(strike[-1]+50)
            premium.append(strike[-1]* (0.85/100))
            twodll.append(derivativehistorycallgetlowvalue(symbol,start_date,end_date,instrumentType,expiry_date,strikePrice=strike[-1]))
        else:
            break
    calldf = pd.DataFrame({"strike":strike,"premium":premium,"twodll":twodll})
    calldf['diff']=round(calldf['twodll']-calldf['premium'],2)
    print (calldf)
    leastdiff = calldf.loc[calldf['diff']>0,'diff'].min()
    leastdiff = round(leastdiff,2)
    print ('leastdiff : '+str(leastdiff))
    if math.isnan(leastdiff):
        callentrystrike = 'NA'
        calltwodll = 'NA'
    else:
        filt = (calldf['diff'] == leastdiff)
        callentrystrike = calldf.loc[filt,'strike'].values[0]
        calltwodll = calldf.loc[filt,'twodll'].values[0]
    print("Call entry strike : ",callentrystrike)
    print("Call entry twoDLL : ",calltwodll)
    return callentrystrike,calltwodll
def get_put_entrystrike(derivative_symbol,start_date,end_date,instrumentType,expiry_date,putendstrike):
    # finding PutEntryStrike 1st row
    symbol = derivative_symbol
    strike = []
    premium = []
    twodll = []
    strike.append(putendstrike)
    temppremium = putendstrike * (0.85/100)
    premium.append(temppremium)
    temptwodll = derivativehistoryputgetlowvalue(symbol,start_date,end_date,instrumentType,expiry_date,strikePrice=strike[0])
    twodll.append(temptwodll)
    # Put Entry strke 2....n rows
    for i in range(1,9):
        if twodll[-1] >= premium[-1]:
            strike.append(strike[-1]-50)
            premium.append(strike[-1]* (0.85/100))
            twodll.append(derivativehistoryputgetlowvalue(symbol,start_date,end_date,instrumentType,expiry_date,strikePrice=strike[-1]))
        else:
            break
    putdf = pd.DataFrame({"strike":strike,"premium":premium,"twodll":twodll})
    putdf['diff']=round(putdf['twodll']-putdf['premium'],2)
    print (putdf)
    leastdiff = putdf.loc[putdf['diff']>0,'diff'].min()
    leastdiff = round(leastdiff,2)
    print ('leastdiff : '+str(leastdiff))
    if math.isnan(leastdiff):
        putentrystrike = 'NA'
        puttwodll = 'NA'
    else:
        filt = (putdf['diff'] == leastdiff)
        putentrystrike = putdf.loc[filt,'strike'].values[0]
        puttwodll = putdf.loc[filt,'twodll'].values[0]
    print("Put entry strike : ",putentrystrike)
    print("Put entry twoDLL : ",puttwodll)
    return putentrystrike,puttwodll

def expiry_history_dates(symbol,start_date,end_date):
  nsefetch_url = "https://www.nseindia.com/api/historical/fo/derivatives/meta?&from="+start_date+"&to="+end_date+"&symbol="+symbol+""
  payload = nsefetch(nsefetch_url)
  return payload
def spot_price(symbol,start_date,end_date):
  data = capital_market.index_data(index=symbol,from_date=start_date,to_date=end_date)
  filt = (data['TIMESTAMP'] == end_date)
  result = data.loc[filt,'CLOSE_INDEX_VAL'].values[0]
  return float(result)

def callentry_YN(symbol,start_date,end_date,expiry_date,strikePrice,CallEntry):
    optionType="CE"
    instrumentType = "options"
    expiry_date = datetime.strptime(expiry_date,"%d-%m-%Y")
    expiry_date = expiry_date.strftime("%d-%b-%Y")
    df = pd.DataFrame(derivative_history(symbol,start_date,end_date,instrumentType,expiry_date,strikePrice,optionType))
    end_date = datetime.strptime(end_date,"%d-%m-%Y")
    end_date = end_date.strftime("%d-%b-%Y")
    filt = (df['FH_TIMESTAMP'] == end_date)
    low = float(df.loc[filt,'FH_TRADE_LOW_PRICE'].values[0])
    if low < CallEntry:
      return "Y"
    else:
      return "N"

def putentry_YN(symbol,start_date,end_date,expiry_date,strikePrice,PutEntry):
    optionType="PE"
    instrumentType = "options"
    expiry_date = datetime.strptime(expiry_date,"%d-%m-%Y")
    expiry_date = expiry_date.strftime("%d-%b-%Y")
    df = pd.DataFrame(derivative_history(symbol,start_date,end_date,instrumentType,expiry_date,strikePrice,optionType))
    end_date = datetime.strptime(end_date,"%d-%m-%Y")
    end_date = end_date.strftime("%d-%b-%Y")
    filt = (df['FH_TIMESTAMP'] == end_date)
    low = float(df.loc[filt,'FH_TRADE_LOW_PRICE'].values[0])
    if low < CallEntry:
      return "Y"
    else:
      return "N"

def call_exit_price(symbol,start_date,end_date,expiry_date,strikePrice,CallTarget,CallStoploss):
    optionType="CE"
    instrumentType = "options"
    expiry_date = datetime.strptime(expiry_date,"%d-%m-%Y")
    expiry_date = expiry_date.strftime("%d-%b-%Y")
    df = pd.DataFrame(derivative_history(symbol,start_date,end_date,instrumentType,expiry_date,strikePrice,optionType))
    print (df)
    for index, row in df.iterrows():
      print (row['FH_TRADE_LOW_PRICE'])
      if CallTarget <= float(row['FH_TRADE_LOW_PRICE']):
        call_exit_price = row['FH_TRADE_LOW_PRICE']
        call_exit_date = row['FH_TIMESTAMP']
        return call_exit_price,call_exit_date
      elif CallStoploss >= float(row['FH_TRADE_HIGH_PRICE']):
        call_exit_price = row['FH_TRADE_HIGH_PRICE']
        call_exit_date = row['FH_TIMESTAMP']
        return call_exit_price,call_exit_date
      else:
        call_exit_price = 'NA'
        call_exit_date = 'NA'
        return call_exit_price,call_exit_date
def put_exit_price(symbol,start_date,end_date,expiry_date,strikePrice,CallTarget,CallStoploss):
    optionType="PE"
    instrumentType = "options"
    expiry_date = datetime.strptime(expiry_date,"%d-%m-%Y")
    expiry_date = expiry_date.strftime("%d-%b-%Y")
    df = pd.DataFrame(derivative_history(symbol,start_date,end_date,instrumentType,expiry_date,strikePrice,optionType))
    print (df)
    for index, row in df.iterrows():
      print (row['FH_TRADE_LOW_PRICE'])
      if CallTarget <= float(row['FH_TRADE_LOW_PRICE']):
        call_exit_price = row['FH_TRADE_LOW_PRICE']
        call_exit_date = row['FH_TIMESTAMP']
        return call_exit_price,call_exit_date
      elif CallStoploss >= float(row['FH_TRADE_HIGH_PRICE']):
        call_exit_price = row['FH_TRADE_HIGH_PRICE']
        call_exit_date = row['FH_TIMESTAMP']
        return call_exit_price,call_exit_date
      else:
        call_exit_price = 'NA'
        call_exit_date = 'NA'
        return call_exit_price,call_exit_date
def backtest(index_symbol,derivative_symbol,start_date,end_date,instrumentType,expiry_date):
    print(start_date)
    print(end_date)
    print(expiry_date)
    expiry_date_temp = expiry_history_dates(derivative_symbol,start_date,end_date)
    expiry_date_list = expiry_date_temp['expiryDatesByInstrument']['OPTIDX']
    print(expiry_date_list)
    callendstrike,putendstrike = get_end_strike_value(index_symbol,start_date,end_date,expiry_date,instrumentType)
    expiry_date = datetime.strptime(expiry_date,"%d-%m-%Y")
    print(expiry_date)
    expiry_date =expiry_date.strftime("%d-%b-%Y")
    print(expiry_date)
    index = expiry_date_list.index(expiry_date)
    #The expiry dates is a list that starts with the selected expiry date and ends with the end of the expiry_date_list
    expiry_dates = expiry_date_list[index:-1]
    callentrystrike = 'NA'
    putentrystrike = 'NA'
    for item in expiry_dates:
      if callentrystrike == 'NA':
        expiry_date = datetime.strptime(item,"%d-%b-%Y")
        expiry_date = expiry_date.strftime("%d-%m-%Y")
        print ("--------Calculating Call entry strike for expiry date : "+expiry_date)
        callentrystrike,calltwodll = get_call_entrystrike(derivative_symbol,start_date,end_date,instrumentType,expiry_date,callendstrike)

    Call_expiry_date = expiry_date
    CallEntry = 0.9 * calltwodll
    CallTarget = CallEntry * 0.25
    CallStoploss = CallEntry * 1.75
    print("CallEntry : "+str(CallEntry))
    print("CallTarget :" +str(CallTarget))
    print("CallStoploss : "+str(CallStoploss))


    for item in expiry_dates:
      if putentrystrike == 'NA':
        expiry_date = datetime.strptime(item,"%d-%b-%Y")
        expiry_date = expiry_date.strftime("%d-%m-%Y")
        print ("--------Calculating Put entry strike for expiry date : "+expiry_date)
        putentrystrike,puttwodll = get_put_entrystrike(derivative_symbol,start_date,end_date,instrumentType,expiry_date,putendstrike)

    put_expiry_date = expiry_date
    PutEntry = 0.9 * puttwodll
    PutTarget = PutEntry * 0.25
    PutStoploss = PutEntry * 1.75
    print("PutEntry : "+str(PutEntry))
    print("PutTarget :" +str(PutTarget))
    print("PutStoploss : "+str(PutStoploss))
    # Clearing all data for the next run
    start_date = ""
    end_date = ""
    expiry_date = ""
    expiry_date_list = ""
    expiry_date_picker = ""
    expiry_date_selected = ""
    return callentrystrike,calltwodll,Call_expiry_date,CallEntry,CallTarget,CallStoploss,putentrystrike,puttwodll,put_expiry_date,PutEntry,PutTarget,PutStoploss

# %% [markdown]
# Test Loop

# %%
# @title
index_symbol = 'NIFTY 50'
derivative_symbol = "NIFTY"
start_date = "02-01-2024"
end_date = "03-01-2024"
expiry_date = "11-01-2024"
instrumentType = "options"
callentrystrike,calltwodll,Call_expiry_date,CallEntry,CallTarget,CallStoploss,putentrystrike,puttwodll,put_expiry_date,PutEntry,PutTarget,PutStoploss = backtest(index_symbol,derivative_symbol,start_date,end_date,instrumentType,expiry_date)
print(callentrystrike)
print(calltwodll)
print(Call_expiry_date)
print(CallEntry)
print(CallTarget)
print(CallStoploss)
print(putentrystrike)
print(puttwodll)
print(put_expiry_date)
print(PutEntry)
print(PutTarget)
print(PutStoploss)

# %% [markdown]
# #Main loop

# %%
index_symbol = 'NIFTY 50'
derivative_symbol = "NIFTY"
instrumentType = "options"
worksheet = gc.open_by_key('1KWaQRcYOP_SiAT7wjsWDNvPtj9duiupsTILWr0QJk64').sheet1
#rows = worksheet.get_all_values()
#df = pd.DataFrame.from_records(rows[1:],columns=rows[0])
df = pd.DataFrame(worksheet.get_all_records())
for i in df.index:
  if df.loc[i,"call_entry_strike"]:
    pass
  else:
    x = i+2
    start_date = df.loc[i,"start_date"]
    end_date = df.loc[i,"end_date"]
    expiry_date = df.loc[i,"expiry_date"]
    execution_date = df.loc[i,"execution_date"]
    callentrystrike,calltwodll,Call_expiry_date,CallEntry,CallTarget,CallStoploss,putentrystrike,puttwodll,put_expiry_date,PutEntry,PutTarget,PutStoploss = backtest(index_symbol,derivative_symbol,start_date,end_date,instrumentType,expiry_date)
    worksheet.update_cell(x,7,float(callentrystrike))
    worksheet.update_cell(x,8,CallEntry)
    worksheet.update_cell(x,9,CallTarget)
    worksheet.update_cell(x,10,CallStoploss)
    worksheet.update_cell(x,11,Call_expiry_date)
    worksheet.update_cell(x,16,float(putentrystrike))
    worksheet.update_cell(x,17,PutEntry)
    worksheet.update_cell(x,18,PutTarget)
    worksheet.update_cell(x,19,PutStoploss)
    worksheet.update_cell(x,20,put_expiry_date)
    spot = spot_price(index_symbol,start_date,end_date)
    worksheet.update_cell(x,6,spot)
    callentry_yn = callentry_YN(derivative_symbol,start_date,execution_date,Call_expiry_date,callentrystrike,CallEntry)
    worksheet.update_cell(x,12,callentry_yn)
    call_ep,call_ed = call_exit_price(derivative_symbol,execution_date,call_expiry_date,call_expiry_date,callentrystrike,CallTarget,CallStoploss)
    worksheet.update_cell(x,13,call_ep)
    worksheet.update_cell(x,14,call_ed)
    putentry_yn = putentry_YN(derivative_symbol,start_date,execution_date,put_expiry_date,putentrystrike,PutEntry)
00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '287.10', 'FH_TRADE_HIGH_PRICE': '449.00', 'FH_TRADE_LOW_PRICE': '251.70', 'FH_CLOSING_PRICE': '319.45', 'FH_LAST_TRADED_PRICE': '260.40', 'FH_PREV_CLS': '327.05', 'FH_SETTLE_PRICE': '319.45', 'FH_TOT_TRADED_QTY': '6781150', 'FH_TOT_TRADED_VAL': '147931878917.50', 'FH_OPEN_INT': '1224850', 'FH_CHANGE_IN_OI': '-68100.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '01-Jan-2024', 'TIMESTAMP': '2023-12-31T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21741.9, 'CALCULATED_PREMIUM_VAL': 2137153917.5}], 'meta': {'symbol': 'NIFTY', 'optionType': 'CE', 'expiryDate': '04-Jan-2024', 'strikePrice': '21500.00', 'instrumentType': 'OPTIDX', 'year': '2024', 'fromDate': '01-01-2024', 'toDate': '02-01-2024'}}
#    strike  premium  twodll   diff
# 0   21500   182.75   159.5 -23.25
# leastdiff : nan
# Call entry strike :  NA
# Call entry twoDLL :  NA
# --------Calculating Call entry strike for expiry date : 11-01-2024
# {'data': [{'_id': '659415572b5d6a8211b53964', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21500.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '375.75', 'FH_TRADE_HIGH_PRICE': '389.10', 'FH_TRADE_LOW_PRICE': '260.55', 'FH_CLOSING_PRICE': '301.90', 'FH_LAST_TRADED_PRICE': '290.00', 'FH_PREV_CLS': '421.20', 'FH_SETTLE_PRICE': '301.90', 'FH_TOT_TRADED_QTY': '1417000', 'FH_TOT_TRADED_VAL': '30897633355.00', 'FH_OPEN_INT': '209800', 'FH_CHANGE_IN_OI': '80400.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '02-Jan-2024', 'TIMESTAMP': '2024-01-01T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21665.8, 'CALCULATED_PREMIUM_VAL': 432133355}, {'_id': '6592b8922b5d6a8211a33ed6', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21500.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '406.00', 'FH_TRADE_HIGH_PRICE': '521.60', 'FH_TRADE_LOW_PRICE': '354.15', 'FH_CLOSING_PRICE': '421.20', 'FH_LAST_TRADED_PRICE': '358.00', 'FH_PREV_CLS': '417.20', 'FH_SETTLE_PRICE': '421.20', 'FH_TOT_TRADED_QTY': '376100', 'FH_TOT_TRADED_VAL': '8244071312.50', 'FH_OPEN_INT': '129400', 'FH_CHANGE_IN_OI': '-84800.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '01-Jan-2024', 'TIMESTAMP': '2023-12-31T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21741.9, 'CALCULATED_PREMIUM_VAL': 157921312.5}], 'meta': {'symbol': 'NIFTY', 'optionType': 'CE', 'expiryDate': '11-Jan-2024', 'strikePrice': '21500.00', 'instrumentType': 'OPTIDX', 'year': '2024', 'fromDate': '01-01-2024', 'toDate': '02-01-2024'}}
# {'data': [{'_id': '659415562b5d6a8211b4fc85', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21550.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '326.00', 'FH_TRADE_HIGH_PRICE': '353.10', 'FH_TRADE_LOW_PRICE': '232.00', 'FH_CLOSING_PRICE': '265.00', 'FH_LAST_TRADED_PRICE': '255.20', 'FH_PREV_CLS': '383.00', 'FH_SETTLE_PRICE': '265.00', 'FH_TOT_TRADED_QTY': '567300', 'FH_TOT_TRADED_VAL': '12373431445.00', 'FH_OPEN_INT': '44200', 'FH_CHANGE_IN_OI': '33300.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '02-Jan-2024', 'TIMESTAMP': '2024-01-01T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21665.8, 'CALCULATED_PREMIUM_VAL': 148116445}, {'_id': '6592b8922b5d6a8211a36442', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21550.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '351.45', 'FH_TRADE_HIGH_PRICE': '472.05', 'FH_TRADE_LOW_PRICE': '319.40', 'FH_CLOSING_PRICE': '383.00', 'FH_LAST_TRADED_PRICE': '325.90', 'FH_PREV_CLS': '388.95', 'FH_SETTLE_PRICE': '383.00', 'FH_TOT_TRADED_QTY': '23650', 'FH_TOT_TRADED_VAL': '518537335.00', 'FH_OPEN_INT': '10900', 'FH_CHANGE_IN_OI': '-2400.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '01-Jan-2024', 'TIMESTAMP': '2023-12-31T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21741.9, 'CALCULATED_PREMIUM_VAL': 8879835}], 'meta': {'symbol': 'NIFTY', 'optionType': 'CE', 'expiryDate': '11-Jan-2024', 'strikePrice': '21550.00', 'instrumentType': 'OPTIDX', 'year': '2024', 'fromDate': '01-01-2024', 'toDate': '02-01-2024'}}
# {'data': [{'_id': '659415562b5d6a8211b50806', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21600.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '290.05', 'FH_TRADE_HIGH_PRICE': '319.85', 'FH_TRADE_LOW_PRICE': '203.75', 'FH_CLOSING_PRICE': '231.50', 'FH_LAST_TRADED_PRICE': '223.95', 'FH_PREV_CLS': '317.45', 'FH_SETTLE_PRICE': '231.50', 'FH_TOT_TRADED_QTY': '4001150', 'FH_TOT_TRADED_VAL': '87369649180.00', 'FH_OPEN_INT': '345850', 'FH_CHANGE_IN_OI': '254500.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '02-Jan-2024', 'TIMESTAMP': '2024-01-01T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21665.8, 'CALCULATED_PREMIUM_VAL': 944809180}, {'_id': '6592b8922b5d6a8211a32868', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21600.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '322.15', 'FH_TRADE_HIGH_PRICE': '439.35', 'FH_TRADE_LOW_PRICE': '285.80', 'FH_CLOSING_PRICE': '317.45', 'FH_LAST_TRADED_PRICE': '288.15', 'FH_PREV_CLS': '357.75', 'FH_SETTLE_PRICE': '317.45', 'FH_TOT_TRADED_QTY': '540250', 'FH_TOT_TRADED_VAL': '11849326600.00', 'FH_OPEN_INT': '91350', 'FH_CHANGE_IN_OI': '-35550.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '01-Jan-2024', 'TIMESTAMP': '2023-12-31T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21741.9, 'CALCULATED_PREMIUM_VAL': 179926600}], 'meta': {'symbol': 'NIFTY', 'optionType': 'CE', 'expiryDate': '11-Jan-2024', 'strikePrice': '21600.00', 'instrumentType': 'OPTIDX', 'year': '2024', 'fromDate': '01-01-2024', 'toDate': '02-01-2024'}}
# {'data': [{'_id': '659415562b5d6a8211b50fc7', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21650.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '230.00', 'FH_TRADE_HIGH_PRICE': '286.45', 'FH_TRADE_LOW_PRICE': '178.65', 'FH_CLOSING_PRICE': '203.55', 'FH_LAST_TRADED_PRICE': '197.00', 'FH_PREV_CLS': '290.75', 'FH_SETTLE_PRICE': '203.55', 'FH_TOT_TRADED_QTY': '2319000', 'FH_TOT_TRADED_VAL': '50695892965.00', 'FH_OPEN_INT': '294550', 'FH_CHANGE_IN_OI': '233400.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '02-Jan-2024', 'TIMESTAMP': '2024-01-01T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21665.8, 'CALCULATED_PREMIUM_VAL': 489542965}, {'_id': '6592b8922b5d6a8211a38359', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21650.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '283.45', 'FH_TRADE_HIGH_PRICE': '401.40', 'FH_TRADE_LOW_PRICE': '253.35', 'FH_CLOSING_PRICE': '290.75', 'FH_LAST_TRADED_PRICE': '259.00', 'FH_PREV_CLS': '326.45', 'FH_SETTLE_PRICE': '290.75', 'FH_TOT_TRADED_QTY': '466600', 'FH_TOT_TRADED_VAL': '10242138972.50', 'FH_OPEN_INT': '61150', 'FH_CHANGE_IN_OI': '-7250.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '01-Jan-2024', 'TIMESTAMP': '2023-12-31T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21741.9, 'CALCULATED_PREMIUM_VAL': 140248972.5}], 'meta': {'symbol': 'NIFTY', 'optionType': 'CE', 'expiryDate': '11-Jan-2024', 'strikePrice': '21650.00', 'instrumentType': 'OPTIDX', 'year': '2024', 'fromDate': '01-01-2024', 'toDate': '02-01-2024'}}
#    strike  premium  twodll   diff
# 0   21500  182.750  260.55  77.80
# 1   21550  183.175  232.00  48.82
# 2   21600  183.600  203.75  20.15
# 3   21650  184.025  178.65  -5.38
# leastdiff : 20.15
# Call entry strike :  21600
# Call entry twoDLL :  203.75
# CallEntry : 183.375
# CallTarget :45.84375
# CallStoploss : 320.90625
# --------Calculating Put entry strike for expiry date : 04-01-2024
# {'data': [{'_id': '659415562b5d6a8211b4e861', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '04-Jan-2024', 'FH_STRIKE_PRICE': '21900.00', 'FH_OPTION_TYPE': 'PE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '189.55', 'FH_TRADE_HIGH_PRICE': '335.00', 'FH_TRADE_LOW_PRICE': '170.75', 'FH_CLOSING_PRICE': '252.40', 'FH_LAST_TRADED_PRICE': '258.50', 'FH_PREV_CLS': '145.10', 'FH_SETTLE_PRICE': '252.40', 'FH_TOT_TRADED_QTY': '12573100', 'FH_TOT_TRADED_VAL': '278343046597.50', 'FH_OPEN_INT': '1209400', 'FH_CHANGE_IN_OI': '-338050.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '02-Jan-2024', 'TIMESTAMP': '2024-01-01T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21665.8, 'CALCULATED_PREMIUM_VAL': 2992156597.5}, {'_id': '6592b8922b5d6a8211a30394', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '04-Jan-2024', 'FH_STRIKE_PRICE': '21900.00', 'FH_OPTION_TYPE': 'PE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '209.90', 'FH_TRADE_HIGH_PRICE': '237.10', 'FH_TRADE_LOW_PRICE': '92.55', 'FH_CLOSING_PRICE': '145.10', 'FH_LAST_TRADED_PRICE': '203.55', 'FH_PREV_CLS': '194.25', 'FH_SETTLE_PRICE': '145.10', 'FH_TOT_TRADED_QTY': '32589700', 'FH_TOT_TRADED_VAL': '718652386205.00', 'FH_OPEN_INT': '1547450', 'FH_CHANGE_IN_OI': '870450.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '01-Jan-2024', 'TIMESTAMP': '2023-12-31T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21741.9, 'CALCULATED_PREMIUM_VAL': 4937956205}], 'meta': {'symbol': 'NIFTY', 'optionType': 'PE', 'expiryDate': '04-Jan-2024', 'strikePrice': '21900.00', 'instrumentType': 'OPTIDX', 'year': '2024', 'fromDate': '01-01-2024', 'toDate': '02-01-2024'}}
#    strike  premium  twodll  diff
# 0   21900   186.15  170.75 -15.4
# leastdiff : nan
# Put entry strike :  NA
# Put entry twoDLL :  NA
# --------Calculating Put entry strike for expiry date : 11-01-2024
# {'data': [{'_id': '659415562b5d6a8211b4956a', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21900.00', 'FH_OPTION_TYPE': 'PE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '255.65', 'FH_TRADE_HIGH_PRICE': '362.90', 'FH_TRADE_LOW_PRICE': '231.50', 'FH_CLOSING_PRICE': '291.70', 'FH_LAST_TRADED_PRICE': '296.10', 'FH_PREV_CLS': '215.65', 'FH_SETTLE_PRICE': '291.70', 'FH_TOT_TRADED_QTY': '571950', 'FH_TOT_TRADED_VAL': '12687713390.00', 'FH_OPEN_INT': '126300', 'FH_CHANGE_IN_OI': '-78000.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '02-Jan-2024', 'TIMESTAMP': '2024-01-01T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21665.8, 'CALCULATED_PREMIUM_VAL': 162008390}, {'_id': '6592b8922b5d6a8211a39f28', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21900.00', 'FH_OPTION_TYPE': 'PE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '274.00', 'FH_TRADE_HIGH_PRICE': '285.75', 'FH_TRADE_LOW_PRICE': '164.65', 'FH_CLOSING_PRICE': '215.65', 'FH_LAST_TRADED_PRICE': '248.85', 'FH_PREV_CLS': '252.30', 'FH_SETTLE_PRICE': '215.65', 'FH_TOT_TRADED_QTY': '878200', 'FH_TOT_TRADED_VAL': '19421126087.50', 'FH_OPEN_INT': '204300', 'FH_CHANGE_IN_OI': '102350.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '01-Jan-2024', 'TIMESTAMP': '2023-12-31T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21741.9, 'CALCULATED_PREMIUM_VAL': 188546087.5}], 'meta': {'symbol': 'NIFTY', 'optionType': 'PE', 'expiryDate': '11-Jan-2024', 'strikePrice': '21900.00', 'instrumentType': 'OPTIDX', 'year': '2024', 'fromDate': '01-01-2024', 'toDate': '02-01-2024'}}
#    strike  premium  twodll  diff
# 0   21900   186.15  164.65 -21.5
# leastdiff : nan
# Put entry strike :  NA
# Put entry twoDLL :  NA
# --------Calculating Put entry strike for expiry date : 18-01-2024
# {'data': [{'_id': '659415572b5d6a8211b5639f', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '18-Jan-2024', 'FH_STRIKE_PRICE': '21900.00', 'FH_OPTION_TYPE': 'PE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '298.05', 'FH_TRADE_HIGH_PRICE': '390.00', 'FH_TRADE_LOW_PRICE': '282.35', 'FH_CLOSING_PRICE': '334.15', 'FH_LAST_TRADED_PRICE': '335.00', 'FH_PREV_CLS': '279.00', 'FH_SETTLE_PRICE': '334.15', 'FH_TOT_TRADED_QTY': '32200', 'FH_TOT_TRADED_VAL': '715844090.00', 'FH_OPEN_INT': '4900', 'FH_CHANGE_IN_OI': '-3200.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '02-Jan-2024', 'TIMESTAMP': '2024-01-01T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21665.8, 'CALCULATED_PREMIUM_VAL': 10664090}, {'_id': '6592b8922b5d6a8211a3932c', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '18-Jan-2024', 'FH_STRIKE_PRICE': '21900.00', 'FH_OPTION_TYPE': 'PE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '309.20', 'FH_TRADE_HIGH_PRICE': '315.50', 'FH_TRADE_LOW_PRICE': '218.60', 'FH_CLOSING_PRICE': '279.00', 'FH_LAST_TRADED_PRICE': '310.20', 'FH_PREV_CLS': '297.55', 'FH_SETTLE_PRICE': '279.00', 'FH_TOT_TRADED_QTY': '31950', 'FH_TOT_TRADED_VAL': '708338947.50', 'FH_OPEN_INT': '8100', 'FH_CHANGE_IN_OI': '1250.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '01-Jan-2024', 'TIMESTAMP': '2023-12-31T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21741.9, 'CALCULATED_PREMIUM_VAL': 8633947.5}], 'meta': {'symbol': 'NIFTY', 'optionType': 'PE', 'expiryDate': '18-Jan-2024', 'strikePrice': '21900.00', 'instrumentType': 'OPTIDX', 'year': '2024', 'fromDate': '01-01-2024', 'toDate': '02-01-2024'}}
# {'data': [{'_id': '659415572b5d6a8211b536ed', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '18-Jan-2024', 'FH_STRIKE_PRICE': '21850.00', 'FH_OPTION_TYPE': 'PE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '278.10', 'FH_TRADE_HIGH_PRICE': '361.95', 'FH_TRADE_LOW_PRICE': '262.75', 'FH_CLOSING_PRICE': '302.35', 'FH_LAST_TRADED_PRICE': '308.40', 'FH_PREV_CLS': '238.35', 'FH_SETTLE_PRICE': '302.35', 'FH_TOT_TRADED_QTY': '17600', 'FH_TOT_TRADED_VAL': '389882457.50', 'FH_OPEN_INT': '3700', 'FH_CHANGE_IN_OI': '-300.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '02-Jan-2024', 'TIMESTAMP': '2024-01-01T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21665.8, 'CALCULATED_PREMIUM_VAL': 5322457.5}, {'_id': '6592b8922b5d6a8211a32f8b', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '18-Jan-2024', 'FH_STRIKE_PRICE': '21850.00', 'FH_OPTION_TYPE': 'PE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '296.95', 'FH_TRADE_HIGH_PRICE': '298.90', 'FH_TRADE_LOW_PRICE': '200.40', 'FH_CLOSING_PRICE': '238.35', 'FH_LAST_TRADED_PRICE': '278.10', 'FH_PREV_CLS': '258.65', 'FH_SETTLE_PRICE': '238.35', 'FH_TOT_TRADED_QTY': '11550', 'FH_TOT_TRADED_VAL': '255156512.50', 'FH_OPEN_INT': '4000', 'FH_CHANGE_IN_OI': '550.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '01-Jan-2024', 'TIMESTAMP': '2023-12-31T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21741.9, 'CALCULATED_PREMIUM_VAL': 2789012.5}], 'meta': {'symbol': 'NIFTY', 'optionType': 'PE', 'expiryDate': '18-Jan-2024', 'strikePrice': '21850.00', 'instrumentType': 'OPTIDX', 'year': '2024', 'fromDate': '01-01-2024', 'toDate': '02-01-2024'}}
# {'data': [{'_id': '659415562b5d6a8211b4de27', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '18-Jan-2024', 'FH_STRIKE_PRICE': '21800.00', 'FH_OPTION_TYPE': 'PE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '229.90', 'FH_TRADE_HIGH_PRICE': '335.00', 'FH_TRADE_LOW_PRICE': '229.90', 'FH_CLOSING_PRICE': '286.00', 'FH_LAST_TRADED_PRICE': '284.85', 'FH_PREV_CLS': '226.70', 'FH_SETTLE_PRICE': '286.00', 'FH_TOT_TRADED_QTY': '107650', 'FH_TOT_TRADED_VAL': '2376939287.50', 'FH_OPEN_INT': '31750', 'FH_CHANGE_IN_OI': '2800.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '02-Jan-2024', 'TIMESTAMP': '2024-01-01T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21665.8, 'CALCULATED_PREMIUM_VAL': 30169287.5}, {'_id': '6592b8922b5d6a8211a326ff', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '18-Jan-2024', 'FH_STRIKE_PRICE': '21800.00', 'FH_OPTION_TYPE': 'PE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '276.90', 'FH_TRADE_HIGH_PRICE': '276.90', 'FH_TRADE_LOW_PRICE': '180.50', 'FH_CLOSING_PRICE': '226.70', 'FH_LAST_TRADED_PRICE': '255.20', 'FH_PREV_CLS': '251.65', 'FH_SETTLE_PRICE': '226.70', 'FH_TOT_TRADED_QTY': '112700', 'FH_TOT_TRADED_VAL': '2482428275.00', 'FH_OPEN_INT': '28950', 'FH_CHANGE_IN_OI': '9350.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '01-Jan-2024', 'TIMESTAMP': '2023-12-31T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21741.9, 'CALCULATED_PREMIUM_VAL': 25568275}], 'meta': {'symbol': 'NIFTY', 'optionType': 'PE', 'expiryDate': '18-Jan-2024', 'strikePrice': '21800.00', 'instrumentType': 'OPTIDX', 'year': '2024', 'fromDate': '01-01-2024', 'toDate': '02-01-2024'}}
#    strike  premium  twodll   diff
# 0   21900  186.150   218.6  32.45
# 1   21850  185.725   200.4  14.67
# 2   21800  185.300   180.5  -4.80
# leastdiff : 14.67
# Put entry strike :  21850
# Put entry twoDLL :  200.4
# PutEntry : 180.36
# PutTarget :45.09
# PutStoploss : 315.63
# {'data': [{'_id': '65955de62b5d6a8211c56599', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21600.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '218.95', 'FH_TRADE_HIGH_PRICE': '218.95', 'FH_TRADE_LOW_PRICE': '114.50', 'FH_CLOSING_PRICE': '124.80', 'FH_LAST_TRADED_PRICE': '122.00', 'FH_PREV_CLS': '231.50', 'FH_SETTLE_PRICE': '124.80', 'FH_TOT_TRADED_QTY': '10557400', 'FH_TOT_TRADED_VAL': '229726789320.00', 'FH_OPEN_INT': '1535850', 'FH_CHANGE_IN_OI': '1190000.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP':
00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '09-Jan-2024', 'TIMESTAMP': '2024-01-08T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21544.85, 'CALCULATED_PREMIUM_VAL': 16605295955}, {'_id': '659bfe852b5d6a8211117397', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21600.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '187.70', 'FH_TRADE_HIGH_PRICE': '203.40', 'FH_TRADE_LOW_PRICE': '62.05', 'FH_CLOSING_PRICE': '69.25', 'FH_LAST_TRADED_PRICE': '64.80', 'FH_PREV_CLS': '193.85', 'FH_SETTLE_PRICE': '69.25', 'FH_TOT_TRADED_QTY': '144271050', 'FH_TOT_TRADED_VAL': '3131282742777.50', 'FH_OPEN_INT': '7503250', 'FH_CHANGE_IN_OI': '5888400.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '08-Jan-2024', 'TIMESTAMP': '2024-01-07T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21513, 'CALCULATED_PREMIUM_VAL': 15028062777.5}, {'_id': '6597f9632b5d6a8211e77e73', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21600.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '211.00', 'FH_TRADE_HIGH_PRICE': '217.65', 'FH_TRADE_LOW_PRICE': '131.15', 'FH_CLOSING_PRICE': '193.85', 'FH_LAST_TRADED_PRICE': '177.95', 'FH_PREV_CLS': '187.85', 'FH_SETTLE_PRICE': '193.85', 'FH_TOT_TRADED_QTY': '42281600', 'FH_TOT_TRADED_VAL': '920842069990.00', 'FH_OPEN_INT': '1614850', 'FH_CHANGE_IN_OI': '-402800.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '05-Jan-2024', 'TIMESTAMP': '2024-01-04T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21710.8, 'CALCULATED_PREMIUM_VAL': 7559509990}, {'_id': '6596b3d62b5d6a8211d80032', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21600.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '129.95', 'FH_TRADE_HIGH_PRICE': '204.00', 'FH_TRADE_LOW_PRICE': '129.95', 'FH_CLOSING_PRICE': '187.85', 'FH_LAST_TRADED_PRICE': '203.00', 'FH_PREV_CLS': '124.80', 'FH_SETTLE_PRICE': '187.85', 'FH_TOT_TRADED_QTY': '19160900', 'FH_TOT_TRADED_VAL': '41720902 ...
#                         _id FH_INSTRUMENT FH_SYMBOL FH_EXPIRY_DT  \
# 0  65955de62b5d6a8211c56599        OPTIDX     NIFTY  11-Jan-2024
# 1  6596b3d62b5d6a8211d80032        OPTIDX     NIFTY  11-Jan-2024
# 2  6597f9632b5d6a8211e77e73        OPTIDX     NIFTY  11-Jan-2024
# 3  659bfe852b5d6a8211117397        OPTIDX     NIFTY  11-Jan-2024
# 4  659d4cc92b5d6a8211213a8f        OPTIDX     NIFTY  11-Jan-2024
# 5  659ea5472b5d6a8211319584        OPTIDX     NIFTY  11-Jan-2024
# 6  659fe87d2b5d6a82114237e8        OPTIDX     NIFTY  11-Jan-2024
#
#   FH_STRIKE_PRICE FH_OPTION_TYPE FH_MARKET_TYPE FH_OPENING_PRICE  \
# 0        21600.00             CE              N           218.95
# 1        21600.00             CE              N           129.95
# 2        21600.00             CE              N           211.00
# 3        21600.00             CE              N           187.70
# 4        21600.00             CE              N            96.30
# 5        21600.00             CE              N            57.65
# 6        21600.00             CE              N           101.25
#
#   FH_TRADE_HIGH_PRICE FH_TRADE_LOW_PRICE  ... FH_SETTLE_PRICE  \
# 0              218.95             114.50  ...          124.80
# 1              204.00             129.95  ...          187.85
# 2              217.65             131.15  ...          193.85
# 3              203.40              62.05  ...           69.25
# 4              180.90              49.15  ...           62.05
# 5              116.05              25.35  ...           92.15
# 6              129.35              15.80  ...        21647.20
#
#   FH_TOT_TRADED_QTY  FH_TOT_TRADED_VAL FH_OPEN_INT FH_CHANGE_IN_OI  \
# 0          10557400    229726789320.00     1535850      1190000.00
# 1          19160900    417209025262.50     2017650       481800.00
# 2          42281600    920842069990.00     1614850      -402800.00
# 3         144271050   3131282742777.50     7503250      5888400.00
# 4         147649200   3205828015955.00     7533700        30450.00
# 5         347095250   7515640926690.00     5466400     -2067300.00
# 6         653113300  14141546661475.00     7907950      2441550.00
#
#   FH_MARKET_LOT FH_TIMESTAMP                 TIMESTAMP FH_UNDERLYING_VALUE  \
# 0            50  03-Jan-2024  2024-01-02T18:30:00.000Z            21517.35
# 1            50  04-Jan-2024  2024-01-03T18:30:00.000Z            21658.60
# 2            50  05-Jan-2024  2024-01-04T18:30:00.000Z            21710.80
# 3            50  08-Jan-2024  2024-01-07T18:30:00.000Z            21513.00
# 4            50  09-Jan-2024  2024-01-08T18:30:00.000Z            21544.85
# 5            50  10-Jan-2024  2024-01-09T18:30:00.000Z            21618.70
# 6            50  11-Jan-2024  2024-01-10T18:30:00.000Z            21647.20
#
#   CALCULATED_PREMIUM_VAL
# 0           1.686949e+09
# 1           3.333585e+09
# 2           7.559510e+09
# 3           1.502806e+10
# 4           1.660530e+10
# 5           1.838353e+10
# 6           3.429938e+10
#
# [7 rows x 23 columns]
# 114.50
# {'data': [{'_id': '65955de72b5d6a8211c5f27d', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '18-Jan-2024', 'FH_STRIKE_PRICE': '21850.00', 'FH_OPTION_TYPE': 'PE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '342.00', 'FH_TRADE_HIGH_PRICE': '391.00', 'FH_TRADE_LOW_PRICE': '332.45', 'FH_CLOSING_PRICE': '384.85', 'FH_LAST_TRADED_PRICE': '384.80', 'FH_PREV_CLS': '302.35', 'FH_SETTLE_PRICE': '384.85', 'FH_TOT_TRADED_QTY': '5250', 'FH_TOT_TRADED_VAL': '116669932.50', 'FH_OPEN_INT': '3350', 'FH_CHANGE_IN_OI': '-350.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '03-Jan-2024', 'TIMESTAMP': '2024-01-02T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21517.35, 'CALCULATED_PREMIUM_VAL': 1957432.5}, {'_id': '659415572b5d6a8211b536ed', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '18-Jan-2024', 'FH_STRIKE_PRICE': '21850.00', 'FH_OPTION_TYPE': 'PE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '278.10', 'FH_TRADE_HIGH_PRICE': '361.95', 'FH_TRADE_LOW_PRICE': '262.75', 'FH_CLOSING_PRICE': '302.35', 'FH_LAST_TRADED_PRICE': '308.40', 'FH_PREV_CLS': '238.35', 'FH_SETTLE_PRICE': '302.35', 'FH_TOT_TRADED_QTY': '17600', 'FH_TOT_TRADED_VAL': '389882457.50', 'FH_OPEN_INT': '3700', 'FH_CHANGE_IN_OI': '-300.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '02-Jan-2024', 'TIMESTAMP': '2024-01-01T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21665.8, 'CALCULATED_PREMIUM_VAL': 5322457.5}, {'_id': '6592b8922b5d6a8211a32f8b', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '18-Jan-2024', 'FH_STRIKE_PRICE': '21850.00', 'FH_OPTION_TYPE': 'PE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE':
18:30:00.000Z', 'FH_UNDERLYING_VALUE': 22097.45, 'CALCULATED_PREMIUM_VAL': 1907161485}, {'_id': '65a15bff2b5d6a82115599ba', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '18-Jan-2024', 'FH_STRIKE_PRICE': '21850.00', 'FH_OPTION_TYPE': 'PE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '200.00', 'FH_TRADE_HIGH_PRICE': '218.90', 'FH_TRADE_LOW_PRICE': '83.85', 'FH_CLOSING_PRICE': '102.85', 'FH_LAST_TRADED_PRICE': '84.75', 'FH_PREV_CLS': '252.65', 'FH_SETTLE_PRICE': '102.85', 'FH_TOT_TRADED_QTY': '64519750', 'FH_TOT_TRADED_VAL': '1417538577920.00', 'FH_OPEN_INT': '2831100', 'FH_CHANGE_IN_OI': '2752650.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '12-Jan-2024', 'TIMESTAMP': '2024-01-11T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21894.55, 'CALCULATED_PREMIUM_VAL': 7782040420}, {'_id': '659fe87d2b5d6a8211424b16', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '18-Jan-2024', 'FH_STRIKE_PRICE': '21850.00', 'FH_OPTION_TYPE': 'PE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '203.95', 'FH_TRADE_HIGH_PRICE': '291.55', 'FH_TRADE_LOW_PRICE': '199.55', 'FH_CLOSING_PRICE': '252.65', 'FH_LAST_TRADED_PRICE': '248.40', 'FH_PREV_CLS': '241.05', 'FH_SETTLE_PRICE': '252.65', 'FH_TOT_TRADED_QTY': '545050', 'FH_TOT_TRADED_VAL': '12040141555.00 ...
#                          _id FH_INSTRUMENT FH_SYMBOL FH_EXPIRY_DT  \
# 0   65955de72b5d6a8211c5f27d        OPTIDX     NIFTY  18-Jan-2024
# 1   6596b3d42b5d6a8211d73dd9        OPTIDX     NIFTY  18-Jan-2024
# 2   6597f9632b5d6a8211e761f8        OPTIDX     NIFTY  18-Jan-2024
# 3   659bfe852b5d6a82111157d3        OPTIDX     NIFTY  18-Jan-2024
# 4   659d4cc92b5d6a8211211a8f        OPTIDX     NIFTY  18-Jan-2024
# 5   659ea5472b5d6a82113184b5        OPTIDX     NIFTY  18-Jan-2024
# 6   659fe87d2b5d6a8211424b16        OPTIDX     NIFTY  18-Jan-2024
# 7   65a15bff2b5d6a82115599ba        OPTIDX     NIFTY  18-Jan-2024
# 8   65a52c737e26484fc01cff84        OPTIDX     NIFTY  18-Jan-2024
# 9   65a67a5d7e26484fc02e0e84        OPTIDX     NIFTY  18-Jan-2024
# 10  65a7ea157e26484fc0412b42        OPTIDX     NIFTY  18-Jan-2024
# 11  65a91d297e26484fc050a7f8        OPTIDX     NIFTY  18-Jan-2024
#
#    FH_STRIKE_PRICE FH_OPTION_TYPE FH_MARKET_TYPE FH_OPENING_PRICE  \
# 0         21850.00             PE              N           342.00
# 1         21850.00             PE              N           310.00
# 2         21850.00             PE              N           230.45
# 3         21850.00             PE              N           224.45
# 4         21850.00             PE              N           245.00
# 5         21850.00             PE              N           337.95
# 6         21850.00             PE              N           203.95
# 7         21850.00             PE              N           200.00
# 8         21850.00             PE              N            65.25
# 9         21850.00             PE              N            33.75
# 10        21850.00             PE              N           137.00
# 11        21850.00             PE              N           288.60
#
#    FH_TRADE_HIGH_PRICE FH_TRADE_LOW_PRICE  ... FH_SETTLE_PRICE  \
#     TIMESTAMP INDEX_NAME  OPEN_INDEX_VAL  HIGH_INDEX_VAL  CLOSE_INDEX_VAL  \
# 0  02-01-2024   NIFTY 50        21751.35         21755.6         21665.80
# 1  03-01-2024   NIFTY 50        21661.10         21677.0         21517.35
#
#    LOW_INDEX_VAL TRADED_QTY  TURN_OVER
# 0       21555.65  263711568   25316.13
# 1       21500.35  311933117   32329.23
# highofstartdate : 21755.6
# lowofstartdate: 21555.65
# highofenddate: 21677.0
# lowofenddate : 21500.35
# maxof2days: 21755.6
# minof2days :21500.35
# bufferhigh : 21788
# bufferlow : 21468
# callendstrike : 21450
# putendstrike : 21800
# 2024-01-04 00:00:00
# 04-Jan-2024
# --------Calculating Call entry strike for expiry date : 04-01-2024
#    strike  premium  twodll   diff
# 0   21450  182.325  192.85  10.52
# 1   21500  182.750  159.50 -23.25
# leastdiff : 10.52
# Call entry strike :  21450
# Call entry twoDLL :  192.85
# CallEntry : 173.565
# CallTarget :43.39125
# CallStoploss : 303.73875
# --------Calculating Put entry strike for expiry date : 04-01-2024
#    strike  premium  twodll  diff
# 0   21800    185.3   108.9 -76.4
# leastdiff : nan
# Put entry strike :  NA
# Put entry twoDLL :  NA
# --------Calculating Put entry strike for expiry date : 11-01-2024
#    strike  premium  twodll  diff
# 0   21800    185.3   180.8  -4.5
# leastdiff : nan
# Put entry strike :  NA
# Put entry twoDLL :  NA
# --------Calculating Put entry strike for expiry date : 18-01-2024
#    strike  premium  twodll   diff
# 0   21800  185.300   229.9  44.60
# 1   21750  184.875   215.0  30.12
# 2   21700  184.450   191.6   7.15
# 3   21650  184.025   173.8 -10.22
# leastdiff : 7.15
# Put entry strike :  21700
# Put entry twoDLL :  191.6
# PutEntry : 172.44
# PutTarget :43.11
# PutStoploss : 301.77
# {'data': [{'_id': '65955de62b5d6a8211c5687d', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '04-Jan-2024', 'FH_STRIKE_PRICE': '21450.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '183.75', 'FH_TRADE_HIGH_PRICE': '205.65', 'FH_TRADE_LOW_PRICE': '73.80', 'FH_CLOSING_PRICE': '89.90', 'FH_LAST_TRADED_PRICE': '91.00', 'FH_PREV_CLS': '238.65', 'FH_SETTLE_PRICE': '89.90', 'FH_TOT_TRADED_QTY': '25622950', 'FH_TOT_TRADED_VAL': '553012013557.50', 'FH_OPEN_INT': '703900', 'FH_CHANGE_IN_OI': '555750.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '03-Jan-2024', 'TIMESTAMP': '2024-01-02T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21517.35, 'CALCULATED_PREMIUM_VAL': 3399736057.5}, {'_id': '659415572b5d6a8211b53b15', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '04-Jan-2024', 'FH_STRIKE_PRICE': '21450.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '310.85', 'FH_TRADE_HIGH_PRICE': '338.05', 'FH_TRADE_LOW_PRICE': '192.85', 'FH_CLOSING_PRICE': '238.65', 'FH_LAST_TRADED_PRICE': '228.60', 'FH_PREV_CLS': '358.35', 'FH_SETTLE_PRICE': '238.65', 'FH_TOT_TRADED_QTY': '2901050', 'FH_TOT_TRADED_VAL': '62905188307.50', 'FH_OPEN_INT': '148150', 'FH_CHANGE_IN_OI': '83700.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '02-Jan-2024', 'TIMESTAMP': '2024-01-01T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21665.8, 'CALCULATED_PREMIUM_VAL': 677665807.5}], 'meta': {'symbol': 'NIFTY', 'optionType': 'CE', 'expiryDate': '04-Jan-2024', 'strikePrice': '21450.00', 'instrumentType': 'OPTIDX', 'year': '2024', 'fromDate': '02-01-2024', 'toDate': '03-01-2024'}}
#                         _id FH_INSTRUMENT FH_SYMBOL FH_EXPIRY_DT  \
# 0  65955de72b5d6a8211c5ea6e        OPTIDX     NIFTY  11-Jan-2024
# 1  6596b3d52b5d6a8211d78d64        OPTIDX     NIFTY  11-Jan-2024
# 2  6597f9632b5d6a8211e75a22        OPTIDX     NIFTY  11-Jan-2024
# 3  659bfe852b5d6a82111176bd        OPTIDX     NIFTY  11-Jan-2024
# 4  659d4cc92b5d6a82112106a9        OPTIDX     NIFTY  11-Jan-2024
# 5  659ea5472b5d6a8211319e4c        OPTIDX     NIFTY  11-Jan-2024
# 6  659fe87d2b5d6a82114246a8        OPTIDX     NIFTY  11-Jan-2024
#
#   FH_STRIKE_PRICE FH_OPTION_TYPE FH_MARKET_TYPE FH_OPENING_PRICE  \
# 0        21450.00             CE              N           289.55
# 1        21450.00             CE              N           226.45
# 2        21450.00             CE              N           296.60
# 3        21450.00             CE              N           291.15
# 4        21450.00             CE              N           193.00
# 5        21450.00             CE              N           149.00
# 6        21450.00             CE              N           259.55
#
#   FH_TRADE_HIGH_PRICE FH_TRADE_LOW_PRICE  ... FH_SETTLE_PRICE  \
# 0              302.20             190.45  ...          202.15
# 1              319.65             218.30  ...          300.90
# 2              335.00             229.75  ...          311.10
# 3              323.85             133.20  ...          145.40
# 4              308.40             127.70  ...          148.50
# 5              247.15              82.90  ...          215.90
# 6              272.25             138.75  ...        21647.20
#
#   FH_TOT_TRADED_QTY FH_TOT_TRADED_VAL FH_OPEN_INT FH_CHANGE_IN_OI  \
# ...
# 0  03-01-2024   NIFTY 50         21661.1        21677.00         21517.35
# 1  04-01-2024   NIFTY 50         21605.8        21685.65         21658.60
#
#    LOW_INDEX_VAL TRADED_QTY  TURN_OVER
# 0       21500.35  311933117   32329.23
# 1       21564.55  339172697   30868.15
# highofstartdate : 21677.0
# lowofstartdate: 21500.35
# highofenddate: 21685.65
# lowofenddate : 21564.55
# maxof2days: 21685.65
# minof2days :21500.35
# bufferhigh : 21718
# bufferlow : 21468
# callendstrike : 21450
# putendstrike : 21750
# 2024-01-04 00:00:00
# 04-Jan-2024
# --------Calculating Call entry strike for expiry date : 04-01-2024
#    strike  premium  twodll   diff
# 0   21450  182.325  113.15 -69.18
# leastdiff : nan
# Call entry strike :  NA
# Call entry twoDLL :  NA
# --------Calculating Call entry strike for expiry date : 11-01-2024
#    strike  premium  twodll   diff
# 0   21450  182.325  190.45   8.12
# 1   21500  182.750  162.35 -20.40
# leastdiff : 8.12
# Call entry strike :  21450
# Call entry twoDLL :  190.45
# CallEntry : 171.405
# CallTarget :42.85125
# CallStoploss : 299.95875
# --------Calculating Put entry strike for expiry date : 04-01-2024
#    strike  premium  twodll   diff
# 0   21750  184.875   140.0 -44.88
# leastdiff : nan
# Put entry strike :  NA
# Put entry twoDLL :  NA
# --------Calculating Put entry strike for expiry date : 11-01-2024
#    strike  premium  twodll   diff
# 0   21750  184.875   128.1 -56.78
# leastdiff : nan
# Put entry strike :  NA
# Put entry twoDLL :  NA
# --------Calculating Put entry strike for expiry date : 18-01-2024
#    strike  premium  twodll  diff
# 0   21750  184.875  182.85 -2.03
# leastdiff : nan
# Put entry strike :  NA
# Put entry twoDLL :  NA
# --------Calculating Put entry strike for expiry date : 25-01-2024
#    strike  premium  twodll   diff
# 0   21750  184.875  225.05  40.18
# 1   21700  184.450  205.20  20.75
# 2   21650  184.025  187.95   3.92
# 3   21600  183.600  171.00 -12.60
# leastdiff : 3.92
# Put entry strike :  21650
# Put entry twoDLL :  187.95
# PutEntry : 169.155
# PutTarget :42.28875
# PutStoploss : 296.02125
# {'data': [{'_id': '659fe87d2b5d6a82114246a8', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21450.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '259.55', 'FH_TRADE_HIGH_PRICE': '272.25', 'FH_TRADE_LOW_PRICE': '138.75', 'FH_CLOSING_PRICE': '194.20', 'FH_LAST_TRADED_PRICE': '196.25', 'FH_PREV_CLS': '215.90', 'FH_SETTLE_PRICE': '21647.20', 'FH_TOT_TRADED_QTY': '6219150', 'FH_TOT_TRADED_VAL': '134636019905.00', 'FH_OPEN_INT': '163300', 'FH_CHANGE_IN_OI': '-147150.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '11-Jan-2024', 'TIMESTAMP': '2024-01-10T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21647.2, 'CALCULATED_PREMIUM_VAL': 1235252405}, {'_id': '659ea5472b5d6a8211319e4c', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21450.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '149.00', 'FH_TRADE_HIGH_PRICE': '247.15', 'FH_TRADE_LOW_PRICE': '82.90', 'FH_CLOSING_PRICE': '215.90', 'FH_LAST_TRADED_PRICE': '222.90', 'FH_PREV_CLS': '148.50', 'FH_SETTLE_PRICE': '215.90', 'FH_TOT_TRADED_QTY': '61928900', 'FH_TOT_TRADED_VAL': '1336041583840.00', 'FH_OPEN_INT': '310450', 'FH_CHANGE_IN_OI': '39800.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '10-Jan-2024', 'TIMESTAMP': '2024-01-09T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21618.7, 'CALCULATED_PREMIUM_VAL': 7666678840}, {'_id': '659d4cc92b5d6a82112106a9', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21450.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '193.00', 'FH_TRADE_HIGH_PRICE': '308.40', 'FH_TRADE_LOW_PRICE': '127.70', 'FH_CLOSING_PRICE': '148.50', 'FH_LAST_TRADED_PRICE': '147.00', 'FH_PREV_CLS': '145.40', 'FH_SETTLE_PRICE': '148.50', 'FH_TOT_TRADED_QTY': '6245800', 'FH_TOT_TRADED_VAL': '135249097712.50', 'FH_OPEN_INT': '270650', 'FH_CHANGE_IN_OI': '-110800.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '09-Jan-2024', 'TIMESTAMP': '2024-01-08T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21544.85, 'CALCULATED_PREMIUM_VAL': 1276687712.5}, {'_id': '659bfe852b5d6a82111176bd', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21450.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '291.15', 'FH_TRADE_HIGH_PRICE': '323.85', 'FH_TRADE_LOW_PRICE': '133.20', 'FH_CLOSING_PRICE': '145.40', 'FH_LAST_TRADED_PRICE': '136.00', 'FH_PREV_CLS': '311.10', 'FH_SETTLE_PRICE': '145.40', 'FH_TOT_TRADED_QTY': '6839150', 'FH_TOT_TRADED_VAL': '147929429052.50', 'FH_OPEN_INT': '381450', 'FH_CHANGE_IN_OI': '288550.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '08-Jan-2024', 'TIMESTAMP': '2024-01-07T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21513, 'CALCULATED_PREMIUM_VAL': 1229661552.5}, {'_id': '6597f9632b5d6a8211e75a22', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21450.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '296.60', 'FH_TRADE_HIGH_PRICE': '335.00', 'FH_TRADE_LOW_PRICE': '229.75', 'FH_CLOSING_PRICE': '311.10', 'FH_LAST_TRADED_PRICE': '295.15', 'FH_PREV_CLS': '300.90', 'FH_SETTLE_PRICE': '311.10', 'FH_TOT_TRADED_QTY': '791000', 'FH_TOT_TRADED_VAL': '17193409285.00', 'FH_OPEN_INT': '92900', 'FH_CHANGE_IN_OI': '9600.00', 'FH_MARKET_LOT': '50', 'FH_TIMESTAMP': '05-Jan-2024', 'TIMESTAMP': '2024-01-04T18:30:00.000Z', 'FH_UNDERLYING_VALUE': 21710.8, 'CALCULATED_PREMIUM_VAL': 226459285}, {'_id': '6596b3d52b5d6a8211d78d64', 'FH_INSTRUMENT': 'OPTIDX', 'FH_SYMBOL': 'NIFTY', 'FH_EXPIRY_DT': '11-Jan-2024', 'FH_STRIKE_PRICE': '21450.00', 'FH_OPTION_TYPE': 'CE', 'FH_MARKET_TYPE': 'N', 'FH_OPENING_PRICE': '226.45', 'FH_TRADE_HIGH_PRICE': '319.65', 'FH_TRADE_LOW_PRICE': '218.30', 'FH_CLOSING_PRICE': '300.90', 'FH_LAST_TRADED_PRICE': '315.70', 'FH_PREV_CLS': '202.15', 'FH_SETTLE_PRICE': '300.90', 'FH_TOT_TRADED_QTY': '408000', 'FH_TOT_TRADED_VAL': '8862752537.50', 'FH ...
#                         _id FH_INSTRUMENT FH_SYMBOL FH_EXPIRY_DT  \
# 0  65955de72b5d6a8211c5ea6e        OPTIDX     NIFTY  11-Jan-2024
# 1  6596b3d52b5d6a8211d78d64        OPTIDX     NIFTY  11-Jan-2024
# 2  6597f9632b5d6a8211e75a22        OPTIDX     NIFTY  11-Jan-2024
# 3  659bfe852b5d6a82111176bd        OPTIDX     NIFTY  11-Jan-2024
# 4  659d4cc92b5d6a82112106a9        OPTIDX     NIFTY  11-Jan-2024
# 5  659ea5472b5d6a8211319e4c        OPTIDX     NIFTY  11-Jan-2024
# 6  659fe87d2b5d6a82114246a8        OPTIDX     NIFTY  11-Jan-2024
#
#   FH_STRIKE_PRICE FH_OPTION_TYPE FH_MARKET_TYPE FH_OPENING_PRICE  \
# 0        21450.00             CE              N           289.55
# 1        21450.00             CE              N           226.45
# 2        21450.00             CE              N           296.60
# 3        21450.00             CE              N           291.15
# 4        21450.00             CE              N           193.00
# 5        21450.00             CE              N           149.00
# 6        21450.00             CE              N           259.55
#
#   FH_TRADE_HIGH_PRICE FH_TRADE_LOW_PRICE  ... FH_SETTLE_PRICE  \
# 0              302.20             190.45  ...          202.15
# 1              319.65             218.30  ...          300.90
# 2              335.00             229.75  ...          311.10
# 3              323.85             133.20  ...          145.40
# 4              308.40             127.70  ...          148.50
# 5              247.15              82.90  ...          215.90
# 6              272.25             138.75  ...        21647.20
#
#   FH_TOT_TRADED_QTY FH_TOT_TRADED_VAL FH_OPEN_INT FH_CHANGE_IN_OI  \
# 11            50  18-Jan-2024  2024-01-17T18:30:00.000Z            21462.25
# 12            50  19-Jan-2024  2024-01-18T18:30:00.000Z            21622.40
# 13            50  20-Jan-2024  2024-01-19T18:30:00.000Z            21571.80
# 14            50  23-Jan-2024  2024-01-22T18:30:00.000Z            21238.80
# 15            50  24-Jan-2024  2024-01-23T18:30:00.000Z            21453.95
# 16            50  25-Jan-2024  2024-01-24T18:30:00.000Z            21352.60
#
#    CALCULATED_PREMIUM_VAL
# 0            1.566647e+08
# 1            1.291791e+08
# 2            1.074166e+08
# 3            1.642052e+08
# 4            1.990769e+08
# 5            1.259876e+08
# 6            1.987453e+08
# 7            1.205607e+08
# 8            4.525776e+07
# 9            4.963898e+07
# 10           7.908173e+08
# 11           3.870438e+08
# 12           1.017171e+10
# 13           8.439788e+09
# 14           5.597033e+09
# 15           5.346556e+08
# 16           6.290130e+08
#
# [17 rows x 23 columns]
# 263.75

# %% [markdown]
# ```
# # Change logs
# ```
# --18/02/2024
#
# Code requests
#
# 1. include date selection in index history ✅
#
# 2. get all expiry date,if leasediff nan ,try with next expiry date ✅
#
# 3. Entry=0.9*2dll; Target=Entry*0.25; Stoploss=Entry*1.75 ✅
#
# --26/02/2024
#
# 1. Include functionality for back testing ✅
#
# --28/02/2024
#
# 1. spot is close price of end date. (from https://www.nseindia.com/reports-indices-historical-index-data) ✅
#
# 2. execution date is user input data for trade execution.
# 3. Call entry (Y/N) go to https://www.nseindia.com/report-detail/fo_eq_security startdate and end date = execution date and the expiry date is the call-expiry-date
# compare low call-entry price with execution day low
# if excution day low < call_entry print yes
# else:
# non
# 4. call-exit_price
#  go to https://www.nseindia.com/report-detail/fo_eq_security
#  start date = execution date
#  end date = call_expiry_date
#  expiry_date = call_expiry_date
#  strike price = call_entry_strike
#  type = CE
#  check for the call target (eg : 45 or below) in  low
#  if found then call exit price = call-target and set the start date to call_exit_date
#  else check call stoploss (eg 320 or 320 above) in HIGH found then call exit price = call-stploss and coressonding start date to call-exit-date
#  else
#  NA

# %%
def get_index_history(symbol,start_date,end_date):
    data = capital_market.index_data(index=symbol,from_date=start_date,to_date=end_date)
    print (data)
    return data
def gethighofstartdate(df,symbol,start_date,end_date):
    filt = (df['TIMESTAMP'] == start_date)
    try:
        result = df.loc[filt,'HIGH_INDEX_VAL'].values[0]
        return float(result)
    except IndexError:
        return "NA"
    except ValueError as ve:
        return ve
symbol = "NIFTY 50"
start_date = "01-01-2024"
end_date = "02-01-2024"
df = get_index_history(symbol,start_date,end_date)
result = gethighofstartdate(df,symbol,start_date,end_date)
print (result)
# Out:
#     TIMESTAMP INDEX_NAME  OPEN_INDEX_VAL  HIGH_INDEX_VAL  CLOSE_INDEX_VAL  \
# 0  01-01-2024   NIFTY 50        21727.75        21834.35          21741.9
# 1  02-01-2024   NIFTY 50        21751.35        21755.60          21665.8
#
#    LOW_INDEX_VAL TRADED_QTY  TURN_OVER
# 0       21680.85  153995217   14184.09
# 1       21555.65  263711568   25316.13
# 21834.35
